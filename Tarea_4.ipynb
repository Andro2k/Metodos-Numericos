# %% [markdown]
# <a href="https://colab.research.google.com/github/Andro2k/Metodos-Numericos/blob/main/Tarea_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **CONJUNTO DE EJERCICIOS**

# %% [markdown]
# ### EJERCICIO 1
# * Utiliza el método de bisección para encontrar soluciones precisas dentro de $10^{-6}$ para la ecuación $𝑥^3−7𝑥^2+ 14𝑥−6 = 0$ en los intervalos dados.
# * $a. [0, 1]$
# * $b. [1, 3.2]$
# * $c. [3.2, 4]$

# %%
def f(x):
    return x**3 - 7*x**2 + 14*x - 6

def bisection_method(a, b, tol=1e-6):
    if f(a) * f(b) >= 0:
        print("El método de bisección no se puede aplicar.")
        return None
    while (b - a) / 2 > tol:
        midpoint = (a + b) / 2
        if f(midpoint) == 0:  # Hemos encontrado la raíz exacta
            return midpoint
        elif f(a) * f(midpoint) < 0:
            b = midpoint
        else:
            a = midpoint
    return (a + b) / 2

intervals = [(0, 1), (1, 3.2), (3.2, 4)]
roots = []

for interval in intervals:
    a, b = interval
    root = bisection_method(a, b)
    if root is not None:
        roots.append(root)
        print(f"Raíz en el intervalo {interval}: {root:.6f}")
    else:
        print(f"No se encontró raíz en el intervalo {interval}.")

# Salidas esperadas
# Raíz en el intervalo [0, 1]: 0.803842
# Raíz en el intervalo [1, 3.2]: 2.128428
# Raíz en el intervalo [3.2, 4]: 3.602948
# Out:
# Raíz en el intervalo (0, 1): 0.585786
# Raíz en el intervalo (1, 3.2): 3.000000
# Raíz en el intervalo (3.2, 4): 3.414214

# %% [markdown]
# ### EJERCICIO 2
# * a. Dibuja las gráficas de $𝑦= 𝑥$ y $𝑦= sin 𝑥$.
# * b. Utiliza el método de bisección para encontrar soluciones precisas dentro de $10^{-10}$ para el primer valor positivo de $𝑥$ con $𝑥= 2 sin 𝑥$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear un rango de valores para x
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y1 = x
y2 = np.sin(x)

# Crear la gráfica
plt.figure(figsize=(10, 5))
plt.plot(x, y1, label='y = x')
plt.plot(x, y2, label='y = sin(x)')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.title('Gráficas de y = x y y = sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import numpy as np

def f(x):
    return 2 * np.sin(x) - x

def bisection_method(a, b, tol=1e-10):
    if f(a) * f(b) >= 0:
        print("El método de bisección no se puede aplicar en este intervalo.")
        return None
    while (b - a) / 2 > tol:
        midpoint = (a + b) / 2
        if f(midpoint) == 0:  # Hemos encontrado la raíz exacta
            return midpoint
        elif f(a) * f(midpoint) < 0:
            b = midpoint
        else:
            a = midpoint
    return (a + b) / 2

# Intervalo inicial para encontrar la primera raíz positiva
a, b = 0, 2

root = bisection_method(a, b)
if root is not None:
    print(f"Primera raíz positiva de x = 2sin(x) en el intervalo [{a}, {b}]: {root:.10f}")
else:
    print(f"No se encontró raíz en el intervalo [{a}, {b}].")
# Out:
# El método de bisección no se puede aplicar en este intervalo.
# No se encontró raíz en el intervalo [0, 2].
